# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("dataset/case_time_series.csv",parse_dates=['Date_YMD'],
                                index_col=['Date_YMD'])

# %%
data.tail()
# Out:
#                          Date  Daily Confirmed  Total Confirmed  \
# Date_YMD
# 2021-09-14  14 September 2021            27502         33315304
# 2021-09-15  15 September 2021            30355         33345659
# 2021-09-16  16 September 2021            34653         33380312
# 2021-09-17  17 September 2021            35354         33415666
# 2021-09-18  18 September 2021            31130         33446796
#
#             Daily Recovered  Total Recovered  Daily Deceased  Total Deceased
# Date_YMD
# 2021-09-14            37993         32514470             281          442938
# 2021-09-15            38353         32552823             432          443370
# 2021-09-16            37888         32590711             318          443688
# 2021-09-17            33833         32624544             285          443973
# 2021-09-18            39652         32664196             306          444279

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 598 entries, 2020-01-30 to 2021-09-18
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             598 non-null    object
#  1   Daily Confirmed  598 non-null    int64
#  2   Total Confirmed  598 non-null    int64
#  3   Daily Recovered  598 non-null    int64
#  4   Total Recovered  598 non-null    int64
#  5   Daily Deceased   598 non-null    int64
#  6   Total Deceased   598 non-null    int64
# dtypes: int64(6), object(1)
# memory usage: 37.4+ KB

# %%
x = data.index
y = data["Total Confirmed"]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,10))
ax1.plot(x, y)
ax2.plot(x, y)

ax2.set_yscale("log")
plt.show()

# %%
plt.bar(x, data["Daily Confirmed"])
plt.show()
